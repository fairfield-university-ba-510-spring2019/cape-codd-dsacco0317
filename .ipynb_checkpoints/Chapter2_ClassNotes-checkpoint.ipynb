# %% [markdown]
# # Kroenke & Auer Chapter 2
# Use this notebook to follow along with the class slides (and textbook).

# %% [markdown]
# ## The Source Code
# In this folder are the source files for the examples in textbook:
# - DBP-e14-MySQL-Cape-Codd-Create-Tables.sql uses SQL Data Definition Language to create and structure the tables needed for our data
# - DBP-e14-MySQL-Cape-Codd-Insert-Data.sql uses SQL Data Manipulation Language to insert data into the tables.
#
# Before just moving on, open each file to see what the code looks like. You will see lots of comments at the top explaining the purpose and provenance of each file. Then there are lots and lots of SQL statements. They may look like jibberish for now, but within a couple weeks you will know enough to be able to write these files for yourself!
#
# ## The Live Database
# To keep things simple, these source files have already been preloaded into a MySQL database on BA Lab server. The commands the system admin used were:
# ```
# mysqladmin create cape_codd
# mysql cape_code <DBP-e14-MySQL-Cape-Codd-Create-Tables.sql
# mysql cape_codd <DBP-e14-MySQL-Cape-Codd-Insert-Data.sql
# ```
# The above statements are in bash, a langauge for unix system administration from the command line. Can you figure out what each line does?
#
# After loading the database, user permissions were then granted separately with the SQL command:
# ```
# GRANT SELECT on cape_codd.* to 'ba510student'@'localhost' IDENTIFIED BY 'ba510';
# ```
#
# The rest of this Notebook will use SQL to extract data from the database.

# %% [markdown]
# ## Connect to the Database
# Fill in the <connect-string> (below) with a properly crafted connect string with the following parameters:
# - method: mysql+pymysql
# - user: ba510student
# - password: ba510
# - host: localhost
# - database name: cape_codd

# %%
# %load_ext sql
# %sql mysql+pymysql://ba510student:ba510@localhost/cape_codd
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: ba510student@cape_codd'

# %%
# %%sql
# SELECT * FROM information_schema.tables WHERE TABLE_TYPE = 'BASE TABLE';
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 8 rows affected.
# [('def', 'cape_codd', 'CATALOG_SKU_2013', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, 1, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'CATALOG_SKU_2014', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, 1, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'CATALOG_SKU_2015', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, 1, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'INVENTORY', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 32, 512, 16384, 0, 16384, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'ORDER_ITEM', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 7, 2340, 16384, 0, 16384, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'RETAIL_ORDER', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2, 8192, 16384, 0, 0, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'SKU_DATA', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 8, 2048, 16384, 0, 0, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'WAREHOUSE', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 4, 4096, 16384, 0, 0, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', '')]

# %% [markdown]
# ## Try out the queries in the class slides
# Each query should be run in a single cell with `%%sql` magic at the top. You will need to add cells as you go along. Tip: use Markdown cells to annotate your queries so you know what they are about. Alternatively, you could use /* */ comments instead. It's up to you.

# %%
# %%sql
# /* *** First SQL Query *** */
# SELECT SKU, SKU_Description, Department, Buyer FROM SKU_DATA ORDER BY SKU_DESCRIPTION, SKU DESC;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 8 rows affected.
# [(101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers'),
#  (101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin'),
#  (100200, 'Std. Scuba Tank, Magenta', 'Water Sports', 'Pete Hansen'),
#  (100100, 'Std. Scuba Tank, Yellow', 'Water Sports', 'Pete Hansen')]

# %%
# %%sql
# SELECT * FROM INVENTORY WHERE QuantityOnHand < 10;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 9 rows affected.
# [(100, 101100, 'Dive Mask, Small Clear', 0, 500),
#  (200, 101100, 'Dive Mask, Small Clear', 0, 500),
#  (100, 201000, 'Half-dome Tent', 2, 100),
#  (400, 201000, 'Half-dome Tent', 0, 250),
#  (200, 202000, 'Half-dome Tent Vestibule', 1, 250),
#  (400, 202000, 'Half-dome Tent Vestibule', 0, 200),
#  (300, 301000, 'Light Fly Climbing Harness', 0, 250),
#  (400, 301000, 'Light Fly Climbing Harness', 0, 250),
#  (400, 302000, 'Locking Carabiner, Oval', 0, 1000)]

# %%
# %%sql
# SELECT DISTINCT Buyer FROM SKU_DATA;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 4 rows affected.
# [('Pete Hansen',), ('Nancy Meyers',), ('Cindy Lo',), ('Jerry Martin',)]

# %%
# %%sql
#
# /* *** CANNOT CREATE VIEWS AS USER *** */
#
# CREATE VIEW SKU_TENTS AS (SELECT SKU, SKU_Description FROM INVENTORY WHERE SKU_Description LIKE '%Tent%')
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# (pymysql.err.OperationalError) (1142, "CREATE VIEW command denied to user 'ba510student'@'localhost' for table 'SKU_TENTS'") [SQL: "/* *** CANNOT CREATE VIEWS AS USER *** */\n\nCREATE VIEW SKU_TENTS AS (SELECT SKU, SKU_Description FROM INVENTORY WHERE SKU_Description LIKE '%%Tent%%')"] (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# %%sql
#
# SELECT * FROM CATALOG_SKU_2014 WHERE DateOnWebsite = '01-Jan-2014';
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 0 rows affected.
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect date value: '01-Jan-2014' for column 'DateOnWebsite' at row 1")
#   result = self._query(query)
# []

# %%
# %%sql
#
# SELECT * FROM SKU_DATA WHERE Buyer IN ('Nancy Meyeres', 'Cindy Lo', 'Jerry Martin');
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 4 rows affected.
# [(201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
#
# SELECT * FROM ORDER_ITEM WHERE ExtendedPrice BETWEEN 100 AND 200;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 4 rows affected.
# [(2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (3000, 101100, 2, Decimal('50.00'), Decimal('100.00')),
#  (2000, 101200, 2, Decimal('50.00'), Decimal('100.00')),
#  (1000, 202000, 1, Decimal('130.00'), Decimal('130.00'))]

# %%
# %%sql
#
# SELECT * FROM SKU_DATA WHERE Buyer LIKE 'N%';
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 2 rows affected.
# [(101100, 'Dive Mask, Small Clear', 'Water Sports', 'Nancy Meyers'),
#  (101200, 'Dive Mask, Med Clear', 'Water Sports', 'Nancy Meyers')]

# %%
# %%sql
#
# SELECT * FROM CATALOG_SKU_2015 WHERE CatalogPage IS NULL;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM SKU_DATA WHERE (SKU>200000 OR SKU_Description LIKE '%TENT%' AND NOT Department = 'Camping');
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 4 rows affected.
# [(201000, 'Half-dome Tent', 'Camping', 'Cindy Lo'),
#  (202000, 'Half-dome Tent Vestibule', 'Camping', 'Cindy Lo'),
#  (301000, 'Light Fly Climbing Harness', 'Climbing', 'Jerry Martin'),
#  (302000, 'Locking Carabiner, Oval', 'Climbing', 'Jerry Martin')]

# %%
# %%sql
#
# SELECT COUNT(SKU) FROM SKU_DATA;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 1 rows affected.
# [(8,)]

# %%
# %%sql
#
# SELECT MAX(SKU) FROM SKU_DATA;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 1 rows affected.
# [(302000,)]

# %%
# %%sql
#
# SELECT (Quantity * Price) AS EP FROM ORDER_ITEM;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 7 rows affected.
# [(Decimal('300.00'),),
#  (Decimal('200.00'),),
#  (Decimal('100.00'),),
#  (Decimal('100.00'),),
#  (Decimal('50.00'),),
#  (Decimal('300.00'),),
#  (Decimal('130.00'),)]

# %%
# %%sql
#
# SELECT * FROM ORDER_ITEM WHERE (Quantity * Price) > 150;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 3 rows affected.
# [(3000, 100200, 1, Decimal('300.00'), Decimal('300.00')),
#  (2000, 101100, 4, Decimal('50.00'), Decimal('200.00')),
#  (1000, 201000, 1, Decimal('300.00'), Decimal('300.00'))]

# %%
# %%sql
#
# /* *** GROUPING *** */
# SELECT SKU, COUNT(SKU), AVG(ExtendedPrice) FROM ORDER_ITEM GROUP BY SKU;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 5 rows affected.
# [(100200, 1, Decimal('300.000000')),
#  (101100, 2, Decimal('150.000000')),
#  (101200, 2, Decimal('75.000000')),
#  (201000, 1, Decimal('300.000000')),
#  (202000, 1, Decimal('130.000000'))]

# %%
# %%sql
#
# /* *** HAVING CLAUSE *** */
# SELECT SKU, SUM(QuantityOnHand) AS QuantOnHand FROM INVENTORY GROUP BY SKU HAVING QuantOnHand < 1000;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 7 rows affected.
# [(100100, Decimal('650')),
#  (100200, Decimal('625')),
#  (101100, Decimal('750')),
#  (101200, Decimal('875')),
#  (201000, Decimal('262')),
#  (202000, Decimal('111')),
#  (301000, Decimal('550'))]

# %%
# %%sql
#
# /* *** ORDER BY WITH GROUPS *** */
# SELECT SKU, SUM(QuantityOnHand) AS QuantOnHand FROM INVENTORY GROUP BY SKU ORDER BY QuantOnHand DESC;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 8 rows affected.
# [(302000, Decimal('2750')),
#  (101200, Decimal('875')),
#  (101100, Decimal('750')),
#  (100100, Decimal('650')),
#  (100200, Decimal('625')),
#  (301000, Decimal('550')),
#  (201000, Decimal('262')),
#  (202000, Decimal('111'))]

# %%
# %%sql
#
# /* *** Fun *** */
# SELECT user, password, host FROM mysql.user;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# (pymysql.err.OperationalError) (1142, "SELECT command denied to user 'ba510student'@'localhost' for table 'user'") [SQL: '/* *** Fun *** */\nSELECT user, password, host FROM mysql.user;'] (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# %%sql
#
# SELECT * FROM information_schema.tables;
# Out:
#  * mysql+pymysql://ba510student:***@localhost/cape_codd
# 69 rows affected.
# [('def', 'information_schema', 'CHARACTER_SETS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 384, 0, 16434816, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=43690', ''),
#  ('def', 'information_schema', 'COLLATIONS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 231, 0, 16704765, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=72628', ''),
#  ('def', 'information_schema', 'COLLATION_CHARACTER_SET_APPLICABILITY', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 195, 0, 16357770, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=86037', ''),
#  ('def', 'information_schema', 'COLUMNS', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=2789', ''),
#  ('def', 'information_schema', 'COLUMN_PRIVILEGES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 2565, 0, 16757145, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=6540', ''),
#  ('def', 'information_schema', 'ENGINES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 490, 0, 16574250, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=34239', ''),
#  ('def', 'information_schema', 'EVENTS', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=618', ''),
#  ('def', 'information_schema', 'FILES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 14468, 0, 16768412, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=1159', ''),
#  ('def', 'information_schema', 'GLOBAL_STATUS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 3268, 0, 16755036, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=5133', ''),
#  ('def', 'information_schema', 'GLOBAL_VARIABLES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 3268, 0, 16755036, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=5133', ''),
#  ('def', 'information_schema', 'KEY_COLUMN_USAGE', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 4637, 0, 16762755, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=3618', ''),
#  ('def', 'information_schema', 'OPTIMIZER_TRACE', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=578524', ''),
#  ('def', 'information_schema', 'PARAMETERS', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=6021', ''),
#  ('def', 'information_schema', 'PARTITIONS', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=5596', ''),
#  ('def', 'information_schema', 'PLUGINS', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=11328', ''),
#  ('def', 'information_schema', 'PROCESSLIST', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=22369', ''),
#  ('def', 'information_schema', 'PROFILING', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 308, 0, 16562084, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=54471', ''),
#  ('def', 'information_schema', 'REFERENTIAL_CONSTRAINTS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 4814, 0, 16767162, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=3485', ''),
#  ('def', 'information_schema', 'ROUTINES', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=582', ''),
#  ('def', 'information_schema', 'SCHEMATA', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 3464, 0, 16738048, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=4843', ''),
#  ('def', 'information_schema', 'SCHEMA_PRIVILEGES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 2179, 0, 16736899, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=7699', ''),
#  ('def', 'information_schema', 'SESSION_STATUS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 3268, 0, 16755036, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=5133', ''),
#  ('def', 'information_schema', 'SESSION_VARIABLES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 3268, 0, 16755036, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=5133', ''),
#  ('def', 'information_schema', 'STATISTICS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 5753, 0, 16752736, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=2916', ''),
#  ('def', 'information_schema', 'TABLES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 9441, 0, 16757775, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=1777', ''),
#  ('def', 'information_schema', 'TABLESPACES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 6951, 0, 16772763, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=2413', ''),
#  ('def', 'information_schema', 'TABLE_CONSTRAINTS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 2504, 0, 16721712, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=6700', ''),
#  ('def', 'information_schema', 'TABLE_PRIVILEGES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 2372, 0, 16748692, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=7073', ''),
#  ('def', 'information_schema', 'TRIGGERS', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=568', ''),
#  ('def', 'information_schema', 'USER_PRIVILEGES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1986, 0, 16726092, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=8447', ''),
#  ('def', 'information_schema', 'VIEWS', 'SYSTEM VIEW', 'InnoDB', 10, 'Dynamic', None, 0, 16384, 0, 0, 8388608, None, None, None, None, 'utf8_general_ci', None, 'max_rows=6797', ''),
#  ('def', 'information_schema', 'INNODB_LOCKS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 31244, 0, 16746784, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=536', ''),
#  ('def', 'information_schema', 'INNODB_TRX', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 4536, 0, 16746912, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=3698', ''),
#  ('def', 'information_schema', 'INNODB_SYS_DATAFILES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 12007, 0, 16773779, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=1397', ''),
#  ('def', 'information_schema', 'INNODB_FT_CONFIG', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1163, 0, 16705332, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=14425', ''),
#  ('def', 'information_schema', 'INNODB_SYS_VIRTUAL', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 17, 0, 11883850, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=986895', ''),
#  ('def', 'information_schema', 'INNODB_CMP', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 25, 0, 13107200, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=671088', ''),
#  ('def', 'information_schema', 'INNODB_FT_BEING_DELETED', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 9, 0, 9437184, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=1864135', ''),
#  ('def', 'information_schema', 'INNODB_CMP_RESET', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 25, 0, 13107200, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=671088', ''),
#  ('def', 'information_schema', 'INNODB_CMP_PER_INDEX', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1755, 0, 16728660, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=9559', ''),
#  ('def', 'information_schema', 'INNODB_CMPMEM_RESET', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 29, 0, 15204352, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=578524', ''),
#  ('def', 'information_schema', 'INNODB_FT_DELETED', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 9, 0, 9437184, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=1864135', ''),
#  ('def', 'information_schema', 'INNODB_BUFFER_PAGE_LRU', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 6669, 0, 16765866, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=2515', ''),
#  ('def', 'information_schema', 'INNODB_LOCK_WAITS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 599, 0, 16749238, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=28008', ''),
#  ('def', 'information_schema', 'INNODB_TEMP_TABLE_INFO', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1011, 0, 16694643, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=16594', ''),
#  ('def', 'information_schema', 'INNODB_SYS_INDEXES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 618, 0, 16615548, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=27147', ''),
#  ('def', 'information_schema', 'INNODB_SYS_TABLES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 2091, 0, 16736364, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=8023', ''),
#  ('def', 'information_schema', 'INNODB_SYS_FIELDS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 594, 0, 16609428, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=28244', ''),
#  ('def', 'information_schema', 'INNODB_CMP_PER_INDEX_RESET', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1755, 0, 16728660, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=9559', ''),
#  ('def', 'information_schema', 'INNODB_BUFFER_PAGE', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 6852, 0, 16766844, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=2448', ''),
#  ('def', 'information_schema', 'INNODB_FT_DEFAULT_STOPWORD', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 56, 0, 14680064, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=299593', ''),
#  ('def', 'information_schema', 'INNODB_FT_INDEX_TABLE', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1054, 0, 16744898, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=15917', ''),
#  ('def', 'information_schema', 'INNODB_FT_INDEX_CACHE', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1054, 0, 16744898, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=15917', ''),
#  ('def', 'information_schema', 'INNODB_SYS_TABLESPACES', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 2133, 0, 16752582, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=7865', ''),
#  ('def', 'information_schema', 'INNODB_METRICS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 2994, 0, 16742448, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=5603', ''),
#  ('def', 'information_schema', 'INNODB_SYS_FOREIGN_COLS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1748, 0, 16738848, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=9597', ''),
#  ('def', 'information_schema', 'INNODB_CMPMEM', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 29, 0, 15204352, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=578524', ''),
#  ('def', 'information_schema', 'INNODB_BUFFER_POOL_STATS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 257, 0, 16332350, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=65280', ''),
#  ('def', 'information_schema', 'INNODB_SYS_COLUMNS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 610, 0, 16613350, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=27503', ''),
#  ('def', 'information_schema', 'INNODB_SYS_FOREIGN', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1752, 0, 16700064, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=9576', ''),
#  ('def', 'information_schema', 'INNODB_SYS_TABLESTATS', 'SYSTEM VIEW', 'MEMORY', 10, 'Fixed', None, 1215, 0, 16763355, 0, 0, None, datetime.datetime(2019, 2, 2, 16, 28, 26), None, None, 'utf8_general_ci', None, 'max_rows=13808', ''),
#  ('def', 'cape_codd', 'CATALOG_SKU_2013', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, 1, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'CATALOG_SKU_2014', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, 1, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'CATALOG_SKU_2015', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 0, 0, 16384, 0, 0, 0, 1, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'INVENTORY', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 32, 512, 16384, 0, 16384, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'ORDER_ITEM', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 7, 2340, 16384, 0, 16384, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'RETAIL_ORDER', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 2, 8192, 16384, 0, 0, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'SKU_DATA', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 8, 2048, 16384, 0, 0, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', ''),
#  ('def', 'cape_codd', 'WAREHOUSE', 'BASE TABLE', 'InnoDB', 10, 'Dynamic', 4, 4096, 16384, 0, 0, 0, None, datetime.datetime(2019, 2, 2, 0, 1, 31), None, None, 'latin1_swedish_ci', None, '', '')]
